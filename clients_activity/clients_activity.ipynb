# %% [markdown]
# # Предсказание покупательской активности клиентов интернет-магазина

# %% [markdown]
# >[Предсказание покупательской активности клиентов интернет-магазина](#scrollTo=ooc_J8gDYac2)
#
# >>>[Описание проекта](#scrollTo=78AdKABgYueI)
#
# >>>[Описание данных](#scrollTo=H6cQIZr3ElW1)
#
# >>[Шаг 1. Загрузка данных](#scrollTo=IjHfzhtUYVaH)
#
# >>>[Импорт библиотек](#scrollTo=v9UAX384ZKPn)
#
# >>>[Загрузка данных](#scrollTo=yxOJ3lvxYVaJ)
#
# >>>[Вывод по шагу 1](#scrollTo=4lkyfcVcYVaK)
#
# >>[Шаг 2. Предобработка данных](#scrollTo=96Gi4lFMYVaK)
#
# >>>[Вывод по шагу 2](#scrollTo=tmgE-ajzYVaL)
#
# >>[Шаг 3. Исследовательский анализ данных](#scrollTo=MiYQgGffYVaL)
#
# >>>[market_file](#scrollTo=Mxoby1NxYVaQ)
#
# >>>>[Количественные признаки](#scrollTo=Mxoby1NxYVaQ)
#
# >>>>>[маркет_актив_6_мес](#scrollTo=VCyHFHgLYVaQ)
#
# >>>>>[маркет_актив_тек_мес](#scrollTo=TOYb45uGYVaQ)
#
# >>>>>[длительность](#scrollTo=4Dw5j6kXYVaR)
#
# >>>>>[акционные покупки](#scrollTo=bvauQnRBYVaR)
#
# >>>>>[средний_просмотр_категорий_за_визит](#scrollTo=ALI0aAMwYVaS)
#
# >>>>>[неоплаченные_продукты_штук_квартал](#scrollTo=iM_4snOJYVaS)
#
# >>>>>[ошибка_сервиса](#scrollTo=dMMHX9XuYVaT)
#
# >>>>>[страниц_за_визит](#scrollTo=Wi5-gOrsYVaT)
#
# >>>>[Категориальные признаки](#scrollTo=Q2UHcArjYVaT)
#
# >>>>>[покупательская_активность](#scrollTo=mXhEL4ugYVaT)
#
# >>>>>[тип_сервиса](#scrollTo=mQNbMs5VYVaU)
#
# >>>>>[разрешить_сообщать](#scrollTo=mOOYLpJjYVaU)
#
# >>>>>[популярная_категория](#scrollTo=BQwoXzqbYVaU)
#
# >>>>>[частота_акционных_покупок](#scrollTo=QhALWWO8YVaU)
#
# >>>>>[Предварительные выводы:](#scrollTo=EOT-XW09YVaU)
#
# >>>[market_money_piv](#scrollTo=hKOjT7VEYVaV)
#
# >>>>>[выручка_2_мес_назад](#scrollTo=hKOjT7VEYVaV)
#
# >>>>>[выручка_1_мес_назад](#scrollTo=9uGoUcsxYVaV)
#
# >>>>>[выручка_текущий_месяц](#scrollTo=zNZwgRW-YVaV)
#
# >>>>>[выручка_3_мес](#scrollTo=A2DWMAelYVaW)
#
# >>>>>[Предварительные выводы:](#scrollTo=QuBSqm6vYVaW)
#
# >>>[market_time_piv](#scrollTo=gcPyFBg4YVaW)
#
# >>>>>[минуты_1_мес_назад](#scrollTo=gcPyFBg4YVaW)
#
# >>>>>[минуты_текущий_месяц](#scrollTo=eLbxZ9OGYVaW)
#
# >>>>>[минуты_2_мес](#scrollTo=fzHIEUUWYVaW)
#
# >>>>>[Предварительные выводы:](#scrollTo=m-8MaLcQYVaW)
#
# >>>[money](#scrollTo=wO1AwbikYVaW)
#
# >>>>>[прибыль](#scrollTo=wO1AwbikYVaW)
#
# >>>[Вывод по шагу 3](#scrollTo=zw4xYT5RYVaX)
#
# >>[Шаг 4. Объединение таблиц](#scrollTo=A8m-j9NvYVaX)
#
# >>>[Вывод по шагу 4](#scrollTo=4gUhT_8kYVaX)
#
# >>[Шаг 5. Корреляционный анализ](#scrollTo=jYf9q3kNYVaX)
#
# >>>[Матрицы корреляции](#scrollTo=jYf9q3kNYVaX)
#
# >>>>[Корреляция по Спирману](#scrollTo=8e9haUqlZsHF)
#
# >>>>[Корреляционное отношение](#scrollTo=TiOv2RlwZx0o)
#
# >>>[Таблицы сопряженности](#scrollTo=zfS58cQHYVaY)
#
# >>>>[покупательская_активность](#scrollTo=QyYNt8U4YVaY)
#
# >>>>[тип_сервиса](#scrollTo=lp9Py0hLYVaZ)
#
# >>>>[разрешить_сообщать](#scrollTo=AnHffH12YVaZ)
#
# >>>[Мультиколлинеарность](#scrollTo=aqkwQdAsYVaa)
#
# >>>[Вывод по шагу 5](#scrollTo=aGrAZeVhYVaa)
#
# >>[Шаг 6. Использование пайплайнов](#scrollTo=_wEHaPHyYVaa)
#
# >>>[Подготовка данных](#scrollTo=CQNf5BCmZ-6_)
#
# >>>[Обучение моделей](#scrollTo=6DKim0d0YVaa)
#
# >>>[Выбор лучшей модели](#scrollTo=CLc7ZLhqYVab)
#
# >>[Шаг 7. Анализ важности признаков](#scrollTo=RmNrXQRTYVac)
#
# >>>[Вывод по шагу 7](#scrollTo=zfl5m-QyYVad)
#
# >>[Шаг 8. Сегментация покупателей](#scrollTo=CBgobhRkYVad)
#
# >>>[Выбор группы покупателей и ее исследование](#scrollTo=QnVjzbBeYVad)
#
# >>>[Предложения, как увеличить покупательскую активность выбранной группы](#scrollTo=nKxp07hKYVae)
#
# >>[Шаг 9. Общий вывод](#scrollTo=G8MsMa42YVae)

# %% [markdown]
# ### Описание проекта
# Интернет-магазин «В один клик», продающий разные товары (для детей, для дома, мелкую бытовую технику, косметику, продукты), столкнулся со снижением активности покупателей. Руководство намерено удерживать активность постоянных клиентов с помощью персонализированных предложений.
#
# Цель проекта — разработка решения, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# Построим модель для предсказания вероятности снижения покупательской активности клиента в следующие три месяца.
#
# Используя данные модели и данные о прибыльности клиентов, выделим сегменты покупателей и разработаем для них персонализированные предложения.

# %% [markdown]
# ### Описание данных
# Данные находятся в четырех таблицах:
# 1. `market_file.csv` (данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении)
#
# |название столбца|содержащиеся данные|
# |:-|:-|
# |`id`|номер покупателя в корпоративной базе данных|
# |`Покупательская активность`|рассчитанный класс покупательской активности (целевой признак): `снизилась` или `прежний уровень`|
# |`Тип сервиса`|уровень сервиса: `премиум` или `стандарт`|
# |`Разрешить сообщать`|информация о том, разрешил ли покупатель присылать ему дополнительные предложения о товаре|
# |`Маркет_актив_6_мес`|среднемесячное значение маркетинговых коммуникаций на покупателя за последние 6 месяцев|
# |`Маркет_актив_тек_мес`|количество маркетинговых коммуникаций в текущем месяце|
# |`Длительность`|количество дней, прошедших с момента регистрации покупателя на сайте|
# |`Акционные_покупки`|среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев|
# |`Популярная_категория`|самая популярная категория товаров у покупателя за последние 6 месяцев|
# |`Средний_просмотр_категорий_за_визит`|среднее количество категорий, просмотренных за визит в течение последнего месяца|
# |`Неоплаченные_продукты_штук_квартал`|общее число неоплаченных товаров в корзине за последние 3 месяца|
# |`Ошибка_сервиса`|число сбоев, которые коснулись покупателя во время посещения сайта|
# |`Страниц_за_визит`|среднее количество страниц, просмотренных за один визит на сайт за последние 3 месяца|
#
# 2. `market_money.csv` (данные о выручке, которую получает магазин с покупателя)
#
# |название столбца|содержащиеся данные|
# |:-|:-|
# |`id`|номер покупателя в корпоративной базе данных|
# |`Период`|название периода, во время которого зафиксирована выручка|
# |`Выручка`|сумма выручки за период|
#
# 3. `market_time.csv` (данные о времени в минутах, которое покупатель провел на сайте в течение периода)
#
# |название столбца|содержащиеся данные|
# |:-|:-|
# |`id`|номер покупателя в корпоративной базе данных|
# |`Период`|название периода, во время которого зафиксировано общее время|
# |`минут`|значение времени, проведённого на сайте, в минутах|
#
# 4. `money.csv` (данные о среднемесячной прибыли от покупателя за последние 3 месяца)
#
# |название столбца|содержащиеся данные|
# |:-|:-|
# |`id`|номер покупателя в корпоративной базе данных|
# |`Прибыль`|значение прибыли|

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %% [markdown]
# ### Импорт библиотек

# %%
! pip install shap

# %%
import pandas as pd
import numpy as np
import shap

import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.mosaicplot import mosaic

from sklearn.model_selection import (
    train_test_split,
    RandomizedSearchCV
)

from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
    MinMaxScaler,
    RobustScaler
)

from sklearn.impute import SimpleImputer

from sklearn.metrics import roc_auc_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer

import warnings
from warnings import simplefilter

# %%
import sklearn
# !pip install -Uq scikit-learn

# %% [markdown]
# ### Загрузка данных
#
# В файле `money.csv` разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.

# %%
try:
    market_file = pd.read_csv('/content/drive/MyDrive/datasets/market_file.csv')
    market_money = pd.read_csv('/content/drive/MyDrive/datasets/market_money.csv')
    market_time = pd.read_csv('/content/drive/MyDrive/datasets/market_time.csv')
    money = pd.read_csv('/content/drive/MyDrive/datasets/money.csv', sep=';', decimal=',')
except:
    market_file = pd.read_csv('/datasets/market_file.csv')
    market_money = pd.read_csv('/datasets/market_money.csv')
    market_time = pd.read_csv('/datasets/market_time.csv')
    money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

print('market_file')
display(market_file.head())
display(market_file.info())


print('market_money')
display(market_money.head())
display(market_money.info())


print('market_time')
display(market_time.head())
display(market_time.info())

print('money')
display(money.head())
display(money.info())
# Out:
# market_file
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# ### Вывод по шагу 1
#
# Сохранили таблицы в переменные. Благодаря учету особенностей разделителей все данные считались корректно.
#
# В данных нет пропусков, все данные представлены адекватными типами.
#
# В данных типа `object` встречаются опечатки, требующие устранения.
#
# Кроме того, непонятно, в чем измеряется прибыль (таблица `money`), поэтому неясно, какие значения считать аномальными. Постараемся разобраться на этапе исследовательского анализа.

# %% [markdown]
# ## Шаг 2. Предобработка данных
#
# Заполнять пропуски и преобразовывать типы данных не нужно. Приведем названия столбцов к нижнему регистру, заменим в них пробелы на нижнее подчеркивание.
#
# Затем найдем и исправим опечатки в данных типа `object`.

# %%
print(market_file.columns)
# Out:
# Index(['id', 'Покупательская активность', 'Тип сервиса', 'Разрешить сообщать',
#        'Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность',
#        'Акционные_покупки', 'Популярная_категория',
#        'Средний_просмотр_категорий_за_визит',
#        'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса',
#        'Страниц_за_визит'],
#       dtype='object')

# %%
market_file.columns = market_file.columns.str.lower().str.replace(' ', '_')
print(market_file.columns)

market_money.columns = market_money.columns.str.lower()
print(market_money.columns)

market_time.columns = market_time.columns.str.lower()
print(market_time.columns)

money.columns = money.columns.str.lower()
print(money.columns)
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')
# Index(['id', 'период', 'выручка'], dtype='object')
# Index(['id', 'период', 'минут'], dtype='object')
# Index(['id', 'прибыль'], dtype='object')

# %%
for column in market_file.select_dtypes(include=['object']).columns:
    print(column)
    print(market_file[column].value_counts())
    print()
# Out:
# покупательская_активность
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
#
# тип_сервиса
# стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64
#
# разрешить_сообщать
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64
#
# популярная_категория
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %% [markdown]
# Опечатки в таблице `market_file` обнаружены только в столбце `тип_сервиса`.
#
# Исправим их и перейдем к информации о периоде из таблиц `market_money` и `market_time`.

# %%
market_file.loc[market_file['тип_сервиса']=='стандартт', 'тип_сервиса'] = 'стандарт'
print(market_file['тип_сервиса'].value_counts())

print('market_money')
print(market_money['период'].value_counts())
print()

print('market_time')
print(market_time['период'].value_counts())
# Out:
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64
# market_money
# текущий_месяц          1300
# предыдущий_месяц       1300
# препредыдущий_месяц    1300
# Name: период, dtype: int64
#
# market_time
# текущий_месяц       1300
# предыдцщий_месяц    1300
# Name: период, dtype: int64

# %% [markdown]
# Значения типа сервиса пришли в норму. Исправим ошибки в словах `препредыдущий` и `предыдцщий`.

# %%
market_money.loc[market_money['период']=='препредыдущий_месяц', 'период'] = 'предпредыдущий_месяц'
print(market_money['период'].value_counts())

market_time.loc[market_time['период']=='предыдцщий_месяц', 'период'] = 'предыдущий_месяц'
print(market_time['период'].value_counts())
# Out:
# текущий_месяц           1300
# предпредыдущий_месяц    1300
# предыдущий_месяц        1300
# Name: период, dtype: int64
# текущий_месяц       1300
# предыдущий_месяц    1300
# Name: период, dtype: int64

# %% [markdown]
# Теперь со строковыми значениями все в порядке.
#
# Проверим наличие дубликатов:
#
# * в таблице `market_file` по значениям столбца `id`
# * в таблице `market_money` по значениям столбцов `id` и `Период`
# * в таблице `market_time` по значениям столбцов `id` и `Период`
# * в таблице `money` по значениям столбца `id`

# %%
print('Дубликаты в market_file', market_file['id'].duplicated().sum())
print('Дубликаты в market_money', market_money[['id', 'период']].duplicated().sum())
print('Дубликаты в market_time', market_time[['id', 'период']].duplicated().sum())
print('Дубликаты в market_file', money['id'].duplicated().sum())
# Out:
# Дубликаты в market_file 0
# Дубликаты в market_money 0
# Дубликаты в market_time 0
# Дубликаты в market_file 0

# %% [markdown]
# Дубликатов нет, можно переходить к исследовательскому анализу.
#
# ### Вывод по шагу 2
#
# Заполнять пропуски, преобразовывать типы данных и обрабатывать дубликаты не понадобилось.
#
# Привели названия столбцов к нижнему регистру, заменили в них пробелы на нижнее подчеркивание. Кириллическое написание оставлено для удобства понимания сути данных.
#
# Найдены и исправлены опечатки в данных типа `object`.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных
#
# Рассмотрим данные о тех клиентах, которые что-либо покупали в каждый из последних трех месяцев. Удалим информацию о тех, кто не совершал покупок в какой-либо из периодов.
# Для этого разделим данные о периоде по самостоятельным столбцам. И добавим столбец с суммой для последующего анализа.

# %%
market_money_piv = pd.pivot_table(
    market_money,
    values='выручка',
    index='id',
    columns='период'
)

market_money_piv.columns = [
    'выручка_2_мес_назад',
    'выручка_1_мес_назад',
    'выручка_текущий_месяц'
]

market_money_piv['выручка_3_мес'] = market_money_piv.apply(np.sum, axis=1)

display(market_money_piv.head())
# Out:
#         выручка_2_мес_назад  выручка_1_мес_назад  выручка_текущий_месяц  \
# id
# 215348                  0.0                  0.0                 3293.1
# 215349               4472.0               5216.0                 4971.6
# 215350               4826.0               5457.5                 5058.4
# 215351               4793.0               6158.0                 6610.4
# 215352               4594.0               5807.5                 5872.5
#
#         выручка_3_мес
# id
# 215348         3293.1
# 215349        14659.6
# 215350        15341.9
# 215351        17561.4
# 215352        16274.0

# %% [markdown]
# Преобразование прошло хорошо.

# %%
market_money_piv = market_money_piv.loc[
    (market_money_piv['выручка_2_мес_назад']>0)
    & (market_money_piv['выручка_1_мес_назад']>0)
    & (market_money_piv['выручка_текущий_месяц']>0)
].reset_index()

print(market_money_piv.shape[0])
# Out:
# 1297

# %% [markdown]
# Удалена информация о 3 клиентах. Преобразуем таблицу `market_time` аналогично таблице `market_money`.

# %%
market_time_piv = pd.pivot_table(
    market_time,
    values='минут',
    index='id',
    columns='период'
)

market_time_piv.columns = [
    'минуты_1_мес_назад',
    'минуты_текущий_месяц'
]

market_time_piv['минуты_2_мес'] = market_time_piv.apply(np.sum, axis=1)
market_time_piv = market_time_piv.reset_index()
display(market_time_piv.head())
# Out:
#        id  минуты_1_мес_назад  минуты_текущий_месяц  минуты_2_мес
# 0  215348                  13                    14            27
# 1  215349                  12                    10            22
# 2  215350                   8                    13            21
# 3  215351                  11                    13            24
# 4  215352                   8                    11            19

# %% [markdown]
# ### `market_file`
#
# #### Количественные признаки
#
# Создадим функцию `show_num`, которая будет принимать название переменной, хранящей таблицу, и столбца в ней, а выводить:
#
# * общее описание данных;
# * гистограмму с наложенным графиком плотности распределения;
# * диаграмму размаха.

# %%
sns.set_style('whitegrid')
def show_num(data, col):
    figure, axs = plt.subplots(1, 2, figsize=(15, 8))
    figure.suptitle(col.title())

    sns.histplot(data[col], bins=50, kde=True, ax=axs[0])
    axs[0].set_title('Гистограмма и плотность расределения')

    sns.boxplot(data=data[col], ax=axs[1])
    axs[1].set_title('Диаграмма размаха')

    plt.show()

    display(data[col].describe().to_frame())

# %% [markdown]
# ##### `маркет_актив_6_мес`

# %%
show_num(market_file, 'маркет_актив_6_мес')
# Out:
#        маркет_актив_6_мес
# count         1300.000000
# mean             4.253769
# std              1.014814
# min              0.900000
# 25%              3.700000
# 50%              4.200000
# 75%              4.900000
# max              6.600000

# %% [markdown]
# В данных нет аномальных значений, почти нет выбросов, распределение стремится к нормальному (немного похоже на полимодальное), медиана очень близка к среднему, стандартное отколение сравнительно невелико, большая часть значений колеблется между 3.7 и 4.9.

# %% [markdown]
# ##### `маркет_актив_тек_мес`

# %%
show_num(market_file, 'маркет_актив_тек_мес')
# Out:
#        маркет_актив_тек_мес
# count           1300.000000
# mean               4.011538
# std                0.696868
# min                3.000000
# 25%                4.000000
# 50%                4.000000
# 75%                4.000000
# max                5.000000

# %% [markdown]
# Построенные графики для визуализации количественных величин неадекватно отражают распределение признака, поскольку он принимает только 3 значения: 3, 4 и 5, и этим напоминает категориальный признак.
#
# Значение 4 преобладает, а 3 и 5 приблизительно поровну, распределение выглядит нормальным.
#
# Аномалий и выбросов в данных нет.
#
# Построим график, который будет лучше соответствовать особенностям признака и более наглядно его визуализировать.

# %%
sns.countplot(
    x=market_file['маркет_актив_тек_мес'].astype(str),
    color='lightblue',
    order=['3', '4', '5']
)
plt.title('Маркет_Актив_Тек_Мес')
plt.show()

# %% [markdown]
# ##### `длительность`

# %%
show_num(market_file, 'длительность')
# Out:
#        длительность
# count   1300.000000
# mean     601.898462
# std      249.856289
# min      110.000000
# 25%      405.500000
# 50%      606.000000
# 75%      806.000000
# max     1079.000000

# %% [markdown]
# В данных нет аномальных значений и выбросов, распределение стремится к нормальному (немного похоже на бимодальное), медиана почти равна среднему, но стандартное отколение довольно большое.
#
# Все пользователи зарегистрировались на сайте больше 3 месяцев назад, некоторые – почти 3 года назад, в среднем они пользуются сайтом около полутора лет.
# Большая часть значений колеблется между 405 и 806.

# %% [markdown]
# ##### `акционные покупки`

# %%
show_num(market_file, 'акционные_покупки')
# Out:
#        акционные_покупки
# count        1300.000000
# mean            0.319808
# std             0.249843
# min             0.000000
# 25%             0.170000
# 50%             0.240000
# 75%             0.300000
# max             0.990000

# %% [markdown]
# В данных нет аномальных значений, почти нет выбросов, распределение стремится к нормальному бимодальному с вершинами чуть больше 0.2 и примерно 0.95. Пользователей можно легко разделить на любителей акций (больше 0.8) и тех, кто редко пользуется акциями (меньше 0.4), между ними окажется очень малочисленная группа обычных покупателей, которые плохо вписываются в оба паттерна.
#
# Из-за неравенства этих категорий медиана далека от среднего, а стандартное отколение велико.
#
# Построим отдельные графики для тех, кто редко пользуется акциями, и любителей акций.

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 8))
figure.suptitle('Покупатели, которые редко пользуются акциями')

sns.histplot(market_file.loc[market_file['акционные_покупки']<0.4, 'акционные_покупки'], bins=100, kde=True, ax=axs[0])
axs[0].set_title('Гистограмма и плотность расределения')

sns.boxplot(data=market_file.loc[market_file['акционные_покупки']<0.4, 'акционные_покупки'], ax=axs[1])
axs[1].set_title('Диаграмма размаха')

plt.show()

display(market_file.loc[market_file['акционные_покупки']<0.4, 'акционные_покупки'].describe())
# Out:
# count    1098.000000
# mean        0.222195
# std         0.069224
# min         0.000000
# 25%         0.160000
# 50%         0.230000
# 75%         0.280000
# max         0.390000
# Name: акционные_покупки, dtype: float64

# %% [markdown]
# Покупатели, не интересующиеся акциями, составляют большинство: 1129 из 1300.
#
# Для этой группы распределение стремится к бимодальному с вершинами 1.5 и примерно 0.23. Поскольку вершины очень близко, а количество наблюдений относительно небольшое, можно предположить, что на большей выборке распределение выглядело бы более похожим на нормальное.

# %%
figure, axs = plt.subplots(1, 2, figsize=(15, 8))
figure.suptitle('Любители акций')

sns.histplot(
    market_file.loc[market_file['акционные_покупки']>0.8, 'акционные_покупки'],
    bins=100,
    kde=True,
    ax=axs[0]
)
axs[0].set_title('Гистограмма и плотность расределения')

sns.boxplot(
    data=market_file.loc[market_file['акционные_покупки']>0.8, 'акционные_покупки'].reset_index(),
    y='акционные_покупки',
    ax=axs[1],
    orient='v'
)
axs[1].set_title('Диаграмма размаха')

plt.show()

display(market_file.loc[market_file['акционные_покупки']>0.8, 'акционные_покупки'].describe())
# Out:
# count    165.000000
# mean       0.945091
# std        0.031654
# min        0.890000
# 25%        0.930000
# 50%        0.940000
# 75%        0.980000
# max        0.990000
# Name: акционные_покупки, dtype: float64

# %% [markdown]
# Для этой группы распределение не похоже на нормальное, что может объясняться малочисленностью группы (165).
#
# По диаграмме размаха отчетливо видно, что подавляющая часть любителей акций стремится не покупать товары без акций.
#
# Убедимся, что покупатели, не попавшие ни в одну из групп (и выглядевшие бы на их графиках как выбросы), малочисленны.

# %%
print(market_file.loc[
    (market_file['акционные_покупки']>=0.4) &
    (market_file['акционные_покупки']<=0.8),
    'акционные_покупки'
].count())
# Out:
# 37

# %% [markdown]
# Добавим в таблицу столбец `частота_акционных_покупок` разбивку покупателей по категориям в зависимости от доли их акционных покупок:
# * `редко` (меньше 0.19);
# * `иногда` (больше либо равно 0.19 и меньше 0.4);
# * `средне` (больше либо равно 0.4 и меньше 0.8);
# * `часто` (больше либо равно 0.8).
#
# Возможно, такой формат представления информации об акциях окажется более подходящим для предсказаний.

# %%
def classify_sales(x):
    if x < 0.19:
        y = 'редко'
    elif x < 0.4:
        y = 'иногда'
    elif x < 0.8:
        y= 'средне'
    else:
        y = 'часто'
    return y

market_file['частота_акционных_покупок'] = market_file['акционные_покупки'].apply(classify_sales)
print(market_file['частота_акционных_покупок'].value_counts())
# Out:
# иногда    698
# редко     400
# часто     165
# средне     37
# Name: частота_акционных_покупок, dtype: int64

# %% [markdown]
# Добавление столбца прошло корректно.

# %% [markdown]
# ##### `средний_просмотр_категорий_за_визит`

# %%
show_num(market_file, 'средний_просмотр_категорий_за_визит')
# Out:
#        средний_просмотр_категорий_за_визит
# count                           1300.00000
# mean                               3.27000
# std                                1.35535
# min                                1.00000
# 25%                                2.00000
# 50%                                3.00000
# 75%                                4.00000
# max                                6.00000

# %% [markdown]
# График плотности распределения неадекватно отражает распределение признака, поскольку он принимает только 6 значений и этим напоминает категориальный признак.
#
# Аномалий и выбросов в данных нет.
#
# Медиана почти равна среднему (3), большинство значений находятся в пределах от 2 до 4 включительно.
#
# Распределение выглядит нормальным, смещенным влево.
#
# Построим график, который будет лучше соответствовать особенностям признака и более наглядно его визуализировать.

# %%
sns.countplot(
    x=market_file['средний_просмотр_категорий_за_визит'].astype(str),
    color='lightblue',
    order=['1', '2', '3', '4', '5', '6']
)
plt.title('Cредний_Просмотр_Категорий_За_Визит')
plt.show()

# %% [markdown]
# ##### `неоплаченные_продукты_штук_квартал`

# %%
show_num(market_file, 'неоплаченные_продукты_штук_квартал')
# Out:
#        неоплаченные_продукты_штук_квартал
# count                         1300.000000
# mean                             2.840000
# std                              1.971451
# min                              0.000000
# 25%                              1.000000
# 50%                              3.000000
# 75%                              4.000000
# max                             10.000000

# %% [markdown]
# В данных нет аномалий, почти нет выбросов.
#
# Распределение похоже на распределение Пуассона. Признак можно рассматривать как число событий (оставление в корзине неоплаченного товара), произошедших за фиксированный промежуток времени (квартал).
#
# Медиана близка к среднему, подавляющее большинство значений находится в пределах от 1 до 4 включительно, при этом имееется длинный хвост (он же верхний "ус" диаграммы размаха) до максимального значения (10).

# %% [markdown]
# ##### `ошибка_сервиса`

# %%
show_num(market_file, 'ошибка_сервиса')
# Out:
#        ошибка_сервиса
# count     1300.000000
# mean         4.185385
# std          1.955298
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          6.000000
# max          9.000000

# %% [markdown]
# В данных нет аномалий и выбросов.
#
# Распределение очень похоже на нормальное с вершиной 4.
#
# Медиана почти равна среднему, подавляющее большинство значений находится в пределах от 3 до 6 включительно, при этом перекос в сторону увеличения (хорошо виден на диаграмме размаха) уравновешивается высокой частотой значений 3 и 2.

# %% [markdown]
# ##### `страниц_за_визит`

# %%
show_num(market_file, 'страниц_за_визит')
# Out:
#        страниц_за_визит
# count       1300.000000
# mean           8.176923
# std            3.978126
# min            1.000000
# 25%            5.000000
# 50%            8.000000
# 75%           11.000000
# max           20.000000

# %% [markdown]
# В данных нет аномалий и выбросов.
#
# Распределение стремится к норальному, смещенному влево.
#
# Медиана очень близка к среднему, подавляющее большинство значений находится в пределах от 5 до 11 включительно, при этом имееется хвост справа (он же верхний "ус" диаграммы размаха) до максимального значения (20).

# %% [markdown]
# #### Категориальные признаки
#
# Создадим функцию `show_cat`, которая будет принимать название переменной, хранящей таблицу, и столбца в ней, а выводить – столбчатую диаграмму и подсчет уникальных значений.

# %%
def show_cat(data, col):
    sns.countplot(
        x=data[col],
        palette='blend:#a27ade,#63cfb0'
    )
    plt.title(f'{col}: столбчатая диаграмма')
    plt.xticks(rotation=90)
    plt.show()

    frame = data[col].value_counts().to_frame()
    frame['доля'] = round((frame[col] / data.shape[0]), 2)
    display(frame)

# %% [markdown]
# ##### `покупательская_активность`

# %%
show_cat(market_file, 'покупательская_активность')
# Out:
#                  покупательская_активность  доля
# Прежний уровень                        802  0.62
# Снизилась                              498  0.38

# %% [markdown]
# Пользователей с прежним уровнем покупательской активности гораздо больше, чем тех, чья активность снизилась, а это наш целевой признак.
#
# Налицо дисбаланс классов.

# %% [markdown]
# ##### `тип_сервиса`

# %%
show_cat(market_file, 'тип_сервиса')
# Out:
#           тип_сервиса  доля
# стандарт          924  0.71
# премиум           376  0.29

# %% [markdown]
# Покупателей с типом сервиса "стандарт" почти в 2.5 раза больше, чем с типом "премиум".

# %% [markdown]
# ##### `разрешить_сообщать`

# %%
show_cat(market_file, 'разрешить_сообщать')
# Out:
#      разрешить_сообщать  доля
# да                  962  0.74
# нет                 338  0.26

# %% [markdown]
# Подавляющее большинство покупателей разрешает присылать им дополнительные предложения о товаре.

# %% [markdown]
# ##### `популярная_категория`

# %%
show_cat(market_file, 'популярная_категория')
# Out:
#                                       популярная_категория  доля
# Товары для детей                                       330  0.25
# Домашний текстиль                                      251  0.19
# Косметика и аксесуары                                  223  0.17
# Техника для красоты и здоровья                         184  0.14
# Мелкая бытовая техника и электроника                   174  0.13
# Кухонная посуда                                        138  0.11

# %% [markdown]
# Самая популярная категория - `Товары для детей`, наименее популярная - `Кухонная посуда`, разница между ними существенная.

# %% [markdown]
# ##### `частота_акционных_покупок`

# %%
show_cat(market_file, 'частота_акционных_покупок')
# Out:
#         частота_акционных_покупок  доля
# иногда                        698  0.54
# редко                         400  0.31
# часто                         165  0.13
# средне                         37  0.03

# %% [markdown]
# Доминирует категория пользователей, иногда пользующихся акциями. Самые малочисленные категории составляют покупатели, чьи акционные покупки составляют больше 0.4.

# %% [markdown]
# ##### Предварительные выводы:
#
# В таблице `market_file` отсутствуют аномальные значения, очень мало выбросов.
#
# Рассмотрено 8 количественных признаков (из них 2 могут быть рассмотрены и как категориальные без дополнительных преобразований) и 4 категориальных.
#
# Не все количественные признаки распределены нормально.
#
# Все категориальные признаки распределены неравномерно. При построении модели для прогнозирования активности необходимо будет учесть дисбаланс классов.

# %% [markdown]
# <span style="color: blue; font-weight: bold">Комментарий ревьюера : </span> ✔️\
# <span style="color: green"> 👍</span>

# %% [markdown]
# ### `market_money_piv`
#
# В этой таблице содержатся только количественные признаки.
#
# ##### `выручка_2_мес_назад `

# %%
show_num(market_money_piv, 'выручка_2_мес_назад')
# Out:
#        выручка_2_мес_назад
# count          1297.000000
# mean           4836.367772
# std             333.438742
# min            4098.000000
# 25%            4585.000000
# 50%            4812.000000
# 75%            5055.000000
# max            5663.000000

# %% [markdown]
# Hаспределение похоже на нормальное, смещенное влево. Диаграмма размаха почти симметричная.
#
# Медиана близка к среднему (приблизительно 4800).
#
# Большинство значений находятся между 4585 и 5055.

# %% [markdown]
# #####  `выручка_1_мес_назад`

# %%
show_num(market_money_piv, 'выручка_1_мес_назад')
# Out:
#        выручка_1_мес_назад
# count          1297.000000
# mean           4948.339630
# std             701.228571
# min            2890.000000
# 25%            4498.500000
# 50%            5005.500000
# 75%            5409.000000
# max            6869.500000

# %% [markdown]
# Аномалий нет.
#
# Имеется несколько выбросов, но они очень близки к границам "усов" диаграммы размаха, и не сильно искажают общую картину.
#
# Распределение стремится к нормальному с вершиной около 5000. Это хорошо сочетается с выручкой за предпредыдущий месяц.
#
# Однако в предыдущем месяце распределение выручки сместилось немного вправо. Это может быть связано, например, с сезонностью или повышением цен.

# %% [markdown]
# #####  `выручка_текущий_месяц`

# %%
show_num(market_money_piv, 'выручка_текущий_месяц')
# Out:
#        выручка_текущий_месяц
# count            1297.000000
# mean             5316.449268
# std              2942.469139
# min              2758.700000
# 25%              4706.600000
# 50%              5180.300000
# 75%              5761.300000
# max            106862.200000

# %% [markdown]
# В данных присутствует аномальное значение. Удалим строку с ним. И построим графики заново.

# %%
market_money_piv = market_money_piv.loc[market_money_piv['выручка_текущий_месяц']<100000]
show_num(market_money_piv, 'выручка_текущий_месяц')
# Out:
#        выручка_текущий_месяц
# count            1296.000000
# mean             5238.096065
# std               834.318717
# min              2758.700000
# 25%              4706.050000
# 50%              5179.950000
# 75%              5759.275000
# max              7799.400000

# %% [markdown]
# Удалили 1 аномальное значение, других аномалий нет.
#
# Есть несколько выбросов, близких к границам "усов" диаграммы размаха.
#
# Распределение стремится к нормальному с вершиной чуть правее 5000. Это хорошо сочетается с динамикой за предпредыдущий и предыдущий месяц. Средняя выручка продолжила постепенно расти. Также растет стандартное отклонение, распределение становится менее пологим.

# %% [markdown]
# #####  `выручка_3_мес`

# %%
show_num(market_money_piv, 'выручка_3_мес')
# Out:
#        выручка_3_мес
# count    1296.000000
# mean    15021.766975
# std      1581.337135
# min     10437.600000
# 25%     13954.325000
# 50%     15072.550000
# 75%     16087.025000
# max     19766.500000

# %% [markdown]
# Аномальных значений нет, есть несколько выбросов вблизи границ "усов" диаграммы размаха.
#
# Общая выручка за 3 месяца, как и ожидалось, распределена более симметрично, но небольшое смещение вправо сохраняется. Медиана почти равна среднему (около 15000), большинство значений между 10437 и 16087.

# %% [markdown]
# ##### Предварительные выводы:
#
# В таблице `market_money_piv` удалено 1 аномальное значение.
#
# Рассмотрено 4 количественных признака: выручка от пользователя за разные месяцы и суммарная выручка от пользователя за три месяца.
#
# Их распределения близки к нормальным. Наблюдается растущая динамика выручки, которая может быть связана с сезонностью (например, если рассматриваемые месяцы - октябрь, ноябрь, декабрь) или/и с ростом цен.

# %% [markdown]
# ### `market_time_piv`
#
# В этой таблице содержатся только количественные признаки.
#
# ##### `минуты_1_мес_назад `

# %%
show_num(market_time_piv, 'минуты_1_мес_назад')
# Out:
#        минуты_1_мес_назад
# count         1300.000000
# mean            13.467692
# std              3.932029
# min              5.000000
# 25%             11.000000
# 50%             13.000000
# 75%             17.000000
# max             23.000000

# %% [markdown]
# Отсутствуют аномальные значения и выбросы.
#
# Распределение стремится к нормальному, смещенному влево.
#
# Медиана близка к среднему (около 13), в предыдущем месяце большинство пользователей проводило на сайте от 11 до 17 минут.

# %% [markdown]
# ##### `минуты_текущий_месяц `

# %%
show_num(market_time_piv, 'минуты_текущий_месяц')
# Out:
#        минуты_текущий_месяц
# count           1300.000000
# mean              13.204615
# std                4.220589
# min                4.000000
# 25%               10.000000
# 50%               13.000000
# 75%               16.000000
# max               23.000000

# %% [markdown]
# Отсутствуют аномальные значения и выбросы.
#
# Распределение стремится к нормальному, смещенному влево, скошенному вправо.
#
# Как и в предыдущем месяце, медиана близка к среднему (около 13). В текущем месяце большинство пользователей проводит на сайте от 10 до 16 минут, то есть на 1 минуту меньше. То же самое среднее сохранилось за счет скошенности распределения.
#
# ##### `минуты_2_мес`

# %%
show_num(market_time_piv, 'минуты_2_мес')
# Out:
#        минуты_2_мес
# count   1300.000000
# mean      26.672308
# std        6.698753
# min        9.000000
# 25%       21.000000
# 50%       27.000000
# 75%       32.000000
# max       45.000000

# %% [markdown]
# Распределение суммы ближе к нормальному. Медиана близка к среднему, выбросов нет.
#
# ##### Предварительные выводы:
#
# В таблице `market_time_piv` отсутствуют аномальные значения и выбросы.
#
# Распределения стремятся к нормальному, смещенному влево, скошенному вправо.
#
# В обоих месяцах медиана близка к среднему (около 13). В текущем месяце большинство пользователей проводит на сайте от 10 до 16 минут, то есть на 1 минуту меньше, чем в предыдущем.
#
# Сумма за 2 месяца распределена более симметрично.

# %% [markdown]
# ### `money`
#
# В этой таблице только 1 столбец. Он содержит количественный признак.
#
# ##### `прибыль`

# %%
show_num(money, 'прибыль')
# Out:
#            прибыль
# count  1300.000000
# mean      3.996631
# std       1.013722
# min       0.860000
# 25%       3.300000
# 50%       4.045000
# 75%       4.670000
# max       7.430000

# %% [markdown]
# По-прежнему остается непонятным, в чем измеряется прибыль.
#
# Но так как выбросов мало, и они не очень сильно удалены от границ "усов" диаграммы размаха, будем считать, что аномалий в данных нет.
#
# Если присутствует смещение разделителя дроби, оно в любом случае нивелируется на этапе масштабирования.
#
# Распределение похоже на нормальное, смещенное вправо. Медиана близка к среднему. График плотности распределения не пологий, немного скошен влево.
#
# ### Вывод по шагу 3
#
# 1. Преобразовали таблицы `market_money` и `market_time`:
# * разделили данные о периодах по самостоятельным столбцам;
# * добавили столбцы с суммарной выручкой за 3 месяца и суммарным временем за 2 месяца;
# * удалили данные о клиентах, которые ничего не покупали в какой-либо из периодов.
#
# 2. Проанализировали данные в таблице `market_file`:
# * отсутствуют аномальные значения, очень мало выбросов;
# * рассмотрели 8 количественных признаков (из них 2 могут быть рассмотрены и как категориальные без дополнительных преобразований) и 4 категориальных;
# * не все количественные признаки распределены нормально;
# * все категориальные признаки распределены неравномерно;
# * при построении модели для прогнозирования активности необходимо будет учесть дисбаланс классов.
#
# 3. Проанализировали данные в таблице `market_money_piv`:
# * удалили 1 аномальное значение;
# * рассмотрели 4 количественных признака (выручка от пользователя за разные месяцы и суммарная выручка от пользователя за три месяца);
# * все распределения близки к нормальным;
# * заметили растующую динамику выручки, которая может быть связана с сезонностью (например, если рассматриваемые месяцы - октябрь, ноябрь, декабрь) или/и с ростом цен.
#
# 4. Проанализировали данные в таблице `market_time_piv`:
# * отсутствуют аномальные значения, очень мало выбросов;
# * рассмотрели 3 количественных признака (время, проведенное на сайте в разные месяцы и суммарно);
# * распределения стремятся к нормальному, смещенному влево, скошенному вправо;
# * в обоих месяцах медиана близка к среднему (около 13);
# * в текущем месяце большинство пользователей проводит на сайте от 10 до 16 минут, то есть на 1 минуту меньше, чем в предыдущем;
# * сумма за 2 месяца распределена более симметрично.
#
# 5. Проанализировали данные в таблице `money` (1 количественный признак):
# * неясно, какие значения можно было бы счесть аномальными, поскольку неизвестно, в чем измеряется прибыль;
# * выбросов мало, и они не очень сильно удалены от границ "усов" диаграммы размаха;
# * распределение похоже на нормальное, смещенное вправо;
# * медиана близка к среднему;
# * график плотности распределения не пологий, немного скошен влево.

# %% [markdown]
# ## Шаг 4. Объединение таблиц
#
# Объединим таблицы `market_file`, `market_money_piv`, `market_time_piv` для моделирования.

# %%
market_full = market_file.merge(
    market_money_piv,
    on='id',
    how='inner'
).merge(
    market_time_piv,
    on='id',
    how='inner'
)

print(market_full.info())
display(market_full.sample(n=10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 0 to 1295
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   покупательская_активность            1296 non-null   object
#  2   тип_сервиса                          1296 non-null   object
#  3   разрешить_сообщать                   1296 non-null   object
#  4   маркет_актив_6_мес                   1296 non-null   float64
#  5   маркет_актив_тек_мес                 1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   популярная_категория                 1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1296 non-null   int64
# ...

# %% [markdown]
# ### Вывод по шагу 4
#
# Объединение таблиц прошло корректно.

# %% [markdown]
# ## Шаг 5. Корреляционный анализ
#
# ### Матрицы корреляции

# %% [markdown]
# #### Корреляция по Спирману
#
# Не все количественные признаки имеют распределение, подходящее для расчета корреляции по Пирсону, поэтому воспользуемся методом Спирмана для построения матрицы корреляции количественных признаков.

# %%
col_num = market_full.select_dtypes(exclude='object').columns
corr_matrix = market_full[col_num].drop('id', axis=1).corr(method='spearman')
display(corr_matrix)

plt.figure(figsize=(12, 12))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    vmin=-1,
    vmax=1,
    center=0
)
plt.show()
# Out:
#                                      маркет_актив_6_мес  маркет_актив_тек_мес  \
# маркет_актив_6_мес                             1.000000              0.061741
# маркет_актив_тек_мес                           0.061741              1.000000
# длительность                                  -0.044445             -0.131967
# акционные_покупки                             -0.276590              0.033099
# средний_просмотр_категорий_за_визит            0.185013             -0.025167
# неоплаченные_продукты_штук_квартал            -0.135045              0.061747
# ошибка_сервиса                                 0.038643              0.087343
# страниц_за_визит                               0.319872              0.003143
# выручка_2_мес_назад                            0.234728             -0.039437
# выручка_1_мес_назад                           -0.003642             -0.027088
# выручка_текущий_месяц                          0.002093             -0.011782
# ...

# %% [markdown]
# Заметны 2 кластера взаимосвязанных признаков (большая часть связей сильная):
# * связанный с выручкой:
#   * `выручка_2_мес_назад`;
#   * `выручка_1_мес_назад`;
#   * `выручка_текущий_месяц`;
#   * `выручка_3_мес`;
# * связанный со временем на сайте:
#   * `минуты_1_мес_назад`;
#   * `минуты_текущий_месяц`;
#   * `минуты_2_мес`.
#
# Других сильных связей нет. Средние:
# * `маркет_актив_6_мес` и кластер времени на сайте;
# * `маркет_актив_6_мес` и `страниц_за_визит`;
# * `акционные_покупки` и `страниц_за_визит`;
# * `акционные_покупки` и кластер времени на сайте;
# * `акционные_покупки` и кластер выручки;
# * `страниц_за_визит` и `выручка_2_мес_назад`;
# * `страниц_за_визит` и кластер времени на сайте;
# * `выручка_2_мес_назад` и кластер времени на сайте.
#
# Кроме того, можно заметить множество слабых связей.

# %% [markdown]
# #### Корреляционное отношение
#
# Чтобы построить матрицу корреляции между категориальными и количественными признаками, воспользуемся корреляционным отношением.
#
# Создадим функцию `calculate_correlation_ratio` для расчета корреляционного отношения и сформируем таблицу, применив ее в цикле к столбцам, содержащим количественные и категориальные признаки.

# %%
col_cat = market_full.select_dtypes(include='object').columns

def calculate_correlation_ratio(num_var, cat_var):

    values = np.array(num_var)
    ss_total = np.sum((values.mean() - values) ** 2)

    cats = np.unique(cat_var, return_inverse = True)[1]

    ss_betweengroups = 0

    for c in np.unique(cats):

        group = values[np.argwhere(cats == c).flatten()]
        ss_betweengroups += len(group) * (group.mean() - values.mean()) ** 2

    return round(np.sqrt(ss_betweengroups/ss_total), 2)

corr_r_matrix = pd.DataFrame(columns=col_num).astype('float')

for col_c in col_cat:
    for col_n in col_num:
        corr_r_matrix.loc[col_c, col_n] = calculate_correlation_ratio(market_full[col_n], market_full[col_c])

display(corr_r_matrix)

plt.figure(figsize=(12, 4))
sns.heatmap(
    corr_r_matrix,
    annot=True,
    cmap='coolwarm',
    vmin=-1,
    vmax=1,
    center=0
)
plt.show()
# Out:
#                              id  маркет_актив_6_мес  маркет_актив_тек_мес  \
# покупательская_активность  0.81                0.39                  0.00
# тип_сервиса                0.10                0.08                  0.07
# разрешить_сообщать         0.03                0.01                  0.07
# популярная_категория       0.18                0.13                  0.11
# частота_акционных_покупок  0.34                0.30                  0.04
#
#                            длительность  акционные_покупки  \
# покупательская_активность          0.06               0.42
# тип_сервиса                        0.31               0.04
# разрешить_сообщать                 0.21               0.02
# популярная_категория               0.05               0.11
# частота_акционных_покупок          0.02               0.99
#
#                            средний_просмотр_категорий_за_визит  \
# покупательская_активность                                 0.37
# ...

# %% [markdown]
# Очень сильных взаимосвязей нет, кроме очевидной связи акционных покупок и присвоенной на их основе частоты.
#
# Сильные:
# * `покупательская_активность` и `страниц_за_визит`;
# * `покупательская_активность` и `минуты_2_мес`.
#
# Средние:
# * `покупательская_активность` и `маркет_актив_6_мес`;
# * `покупательская_активность` и `акционные_покупки`;
# * `покупательская_активность` и `средний_просмотр_категорий_за_визит`;
# * `покупательская_активность` и `неоплаченные_продукты_штук_квартал`;
# * `покупательская_активность` и `выручка_2_мес_назад`;
# * `покупательская_активность` и `минуты_1_мес_назад`;
# * `покупательская_активность` и `минуты_текущий_месяц`;
# * `тип_сервиса` и `длительность`;
# * `частота_акционных_покупок` и `страниц_за_визит`;
# * `частота_акционных_покупок` времени на сайте;
#
#
# Слабые:
# * `разрешить_сообщать` и `длительность`;
# * `популярная_категория` и кластер выручки.

# %% [markdown]
# ### Таблицы сопряженности
#
# Создадим функцию `show_mosaic`, которая будет принимать названия столбцов, содержащих категориальные признаки, и выводить для них таблицы сопряженности и мозаичные диаграммы.
#
# Применим эту функцию ко всем парам категориальных признаков, особенно внимательно изучим получившиеся результаты для столбца `покупательская_активность`.

# %%
def show_mosaic(col_1, col_2):

    display(market_full.pivot_table(
        index=col_1,
        columns=col_2,
        values='id',
        aggfunc='count'
    ))

    fig, dic = mosaic(
        market_full,
        [col_2, col_1],
        gap=0.02,
        title=f'Мозаичная диаграмма\n вертикаль: {col_1} \n горизонталь: {col_2}')
    fig.set_size_inches(12, 12)

    plt.show()

# %% [markdown]
# #### `покупательская_активность`

# %%
show_mosaic('тип_сервиса', 'покупательская_активность')
# Out:
# покупательская_активность  Прежний уровень  Снизилась
# тип_сервиса
# премиум                                206        168
# стандарт                               596        326

# %% [markdown]
# Среди премиум-пользователей доля сниженной активности немного больше.

# %%
show_mosaic('разрешить_сообщать', 'покупательская_активность')
# Out:
# покупательская_активность  Прежний уровень  Снизилась
# разрешить_сообщать
# да                                     591        368
# нет                                    211        126

# %% [markdown]
# Разрешение сообщать дополнительную информацию не связано со снижением активности.

# %%
show_mosaic('популярная_категория', 'покупательская_активность')
# Out:
# покупательская_активность             Прежний уровень  Снизилась
# популярная_категория
# Домашний текстиль                                 149        101
# Косметика и аксесуары                             118        105
# Кухонная посуда                                    72         66
# Мелкая бытовая техника и электроника              147         27
# Техника для красоты и здоровья                    132         50
# Товары для детей                                  184        145

# %% [markdown]
# Доля снизившейся активности меньше среди пользователей, выбирающих категории `Мелкая бытовая техника и электроника` и `Техника для красоты и здоровья`.
#
# Доля снизившейся активности больше среди пользователей, выбирающих категории `Кухонная посуда`, `Косметика и аксессуары` и `Товары для детей`.

# %%
show_mosaic('частота_акционных_покупок', 'покупательская_активность')
# Out:
# покупательская_активность  Прежний уровень  Снизилась
# частота_акционных_покупок
# иногда                                 412        286
# редко                                  348         49
# средне                                   9         28
# часто                                   33        131

# %% [markdown]
# Доля покупателей со сниженной активностью сильно больше среди тех, кто часто, средне или хотя бы иногда пользовался акциями. И заметно ниже среди тех, кто редко пользовался акциями.

# %% [markdown]
# #### `тип_сервиса`

# %%
show_mosaic('разрешить_сообщать', 'тип_сервиса')
# Out:
# тип_сервиса         премиум  стандарт
# разрешить_сообщать
# да                      326       633
# нет                      48       289

# %% [markdown]
# Среди премиум-пользователей больше доля тех, кто разрешил отправлять сообщения.

# %%
show_mosaic('популярная_категория', 'тип_сервиса')
# Out:
# тип_сервиса                           премиум  стандарт
# популярная_категория
# Домашний текстиль                          73       177
# Косметика и аксесуары                      79       144
# Кухонная посуда                            42        96
# Мелкая бытовая техника и электроника       47       127
# Техника для красоты и здоровья             42       140
# Товары для детей                           91       238

# %% [markdown]
# Премиум-пользователи немного чаще выбирают категорию `Косметика и аксессуары`.

# %%
show_mosaic('частота_акционных_покупок', 'тип_сервиса')
# Out:
# тип_сервиса                премиум  стандарт
# частота_акционных_покупок
# иногда                         204       494
# редко                          106       291
# средне                          12        25
# часто                           52       112

# %% [markdown]
# Частота акционных покупок практически не связана с типом сервиса.

# %% [markdown]
# #### `разрешить_сообщать`

# %%
show_mosaic('популярная_категория', 'разрешить_сообщать')
# Out:
# разрешить_сообщать                     да  нет
# популярная_категория
# Домашний текстиль                     186   64
# Косметика и аксесуары                 162   61
# Кухонная посуда                       114   24
# Мелкая бытовая техника и электроника  127   47
# Техника для красоты и здоровья        139   43
# Товары для детей                      231   98

# %% [markdown]
# Пользователи, выбирающие категории `Товары для детей` и `Кухонная посуда`, реже разрешают отправлять сообщения.

# %%
show_mosaic('частота_акционных_покупок', 'разрешить_сообщать')
# Out:
# разрешить_сообщать          да  нет
# частота_акционных_покупок
# иногда                     519  179
# редко                      296  101
# средне                      27   10
# часто                      117   47

# %% [markdown]
# Частота акционных покупок практически не связана с разрешением присылать сообщения.

# %% [markdown]
# ### Мультиколлинеарность
#
# Для качественной работы моделей важно устранить мультиколлинеарность входных признаков. Особенно критично это для линейных моделей.
#
# В пункте 5.1.1 мы обнаружили 2 кластера взаимосвязанных признаков. Из них следует выбрать по одному, оказывающему наибольшее влияние на целевой признак `покупательская активность` (определено в пункте 5.1.2):
# * `минуты_2_мес`;
# * `выручка_2_мес_назад`.
#
# Чтобы исключить утечку данных, нужно было бы узнать, на каких основаниях пользователям присваивался класс активности. Поскольку это невозможно, учтем возможность утечки на этапе оценки качества моделей.
#
# Кроме того, мы вводили собственный категориальный признак `частота_акционных покупок`. На мозаичных диаграммах хорошо заметно влияние категорий на целевой признак, поэтому воспользуемся им для построения моделей. Тогда исключим признак `акционные покупки`.

# %% [markdown]
# ### Вывод по шагу 5
#
# 1. Связи `id` с целевым и некоторыми входными признаками проигнорировали. Скорее всего, это случайные совпадения, и их применение сделает работу модели нестабильной.
# 2. Проанализировали взаимосвязи количественных признаков:
# * заметили 2 кластера взаимосвязанных признаков (большая часть связей сильная):
#   * связанный с выручкой:
#       * `выручка_2_мес_назад`;
#       * `выручка_1_мес_назад`;
#       * `выручка_текущий_месяц`;
#       * `выручка_3_мес`;
#   * связанный со временем на сайте:
#       * `минуты_1_мес_назад`;
#       * `минуты_текущий_месяц`;
#       * `минуты_2_мес`.
# * других сильных связей не обнаружили;
# * обнаружили средние связи:
#   * `маркет_актив_6_мес` и кластер времени на сайте;
#   * `маркет_актив_6_мес` и `страниц_за_визит`;
#   * `акционные_покупки` и `страниц_за_визит`;
#   * `акционные_покупки` и кластер времени на сайте;
#   * `акционные_покупки` и кластер выручки;
#   * `страниц_за_визит` и `выручка_2_мес_назад`;
#   * `страниц_за_визит` и кластер времени на сайте;
#   * `выручка_2_мес_назад` и кластер времени на сайте;
# * обнаружили множество слабых связей.
# 3. Проанализировали связи категориальных и количественных признаков:
# * особенно сильных взаимосвязей не обнаружили;
# * обнаружили сильные связи:
#   * `покупательская_активность` и `страниц_за_визит`;
#   * `покупательская_активность` и `минуты_2_мес`.
# * обнаружили средние связи:
#   * `покупательская_активность` и `маркет_актив_6_мес`;
#   * `покупательская_активность` и `акционные_покупки`;
#   * `покупательская_активность` и `средний_просмотр_категорий_за_визит`;
#   * `покупательская_активность` и `неоплаченные_продукты_штук_квартал`;
#   * `покупательская_активность` и `выручка_2_мес_назад`;
#   * `покупательская_активность` и `минуты_1_мес_назад`;
#   * `покупательская_активность` и `минуты_текущий_месяц`;
#   * `тип_сервиса` и `длительность`;
#   * `частота_акционных_покупок` и `страниц_за_визит`;
#   * `частота_акционных_покупок` времени на сайте;
# * обнаружили слабые связи:
#   * `разрешить_сообщать` и `длительность`;
#   * `популярная_категория` и кластер выручки.
# 4. Проанализировали взаимосвязи категориальных признаков и обнаружили, что:
# * доля покупателей со сниженной активностью сильно больше среди тех, кто часто, средне или хотя бы иногда пользовался акциями;
# * среди премиум-пользователей доля сниженной активности немного больше;
# * доля снизившейся активности меньше среди пользователей, выбирающих категории `Мелкая бытовая техника и электроника` и `Техника для красоты и здоровья`;
# * доля снизившейся активности больше среди пользователей, выбирающих категории `Кухонная посуда`, `Косметика и аксессуары` и `Товары для детей`;
# * разрешение сообщать дополнительную информацию не связано со снижением активности;
# * среди премиум-пользователей доля сниженной активности немного больше.
# 5. Для устранения мультиколлинеарности решили:
# * выбрать из 2 кластеров (пункт 5.1.1) по одному признаку, оказывающему наибольшее влияние на целевой признак `покупательская активность` (определено в пункте 5.1.2):
#   * `минуты_2_мес`;
#   * `выручка_2_мес_назад`;
# * выбрать категориальную форму представления акционной активности.
# 6. Отметили, что может иметь место утечка данных, поскольку неизвестно, на каких основаниях пользователям присваивался класс активности.

# %% [markdown]
# ## Шаг 6. Использование пайплайнов
# Применим изученные модели:
# * К ближайших соседей (`KNeighborsClassifier()`);
# * Дерево решений (`DecisionTreeClassifier()`);
# * Логистическая регрессия (`LogisticRegression()`);
# * Метод опорных векторов (`SVC()`).
#
# Для этого используем пайплайны.

# %% [markdown]
# ### Подготовка данных
# Подготовим обучающую и тестовую выборки c учетом выявленного дисбаланса классов и мультиколлинеарности. А также уменьшим шум в данных, удалив признак `разрешить_сообщать`, никак не влияющий на целевой.
#
# Раздельно обработаем количественные и категориальные признаки в пайплайне, предусмотрев 2 возможных варианта кодирования и 3 - масштабирования.
#
# В имеющихся данных нет пропусков, но стоит учесть, что они могут появиться в будущем, поэтому пропишем заполнение пропусков в пайплайнах.

# %%
market_full['покупательская_активность'] = np.where(
    market_full['покупательская_активность']=='Снизилась',
    1,
    0
)
market_full['покупательская_активность'].sum()
# Out:
# 494

# %%
RANDOM_STATE = 42

X_train, X_test, y_train, y_test = train_test_split(
    market_full.drop(
        [
            'id',
            'покупательская_активность',
            'выручка_1_мес_назад',
            'выручка_текущий_месяц',
            'выручка_3_мес',
            'минуты_1_мес_назад',
            'минуты_текущий_месяц',
            'акционные_покупки',
            'разрешить_сообщать'
        ],
        axis=1
    ),
    market_full['покупательская_активность'],
    test_size = 0.25,
    random_state = RANDOM_STATE,
    stratify = market_full['покупательская_активность']
)

ohe_columns = ['тип_сервиса', 'популярная_категория']
ord_columns = ['частота_акционных_покупок']
num_columns = [
    'маркет_актив_6_мес',
    'маркет_актив_тек_мес',
    'длительность',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал',
    'ошибка_сервиса',
    'страниц_за_визит',
    'выручка_2_мес_назад',
    'минуты_2_мес'
]


ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe',
            OneHotEncoder(drop='first', sparse_output=False)
        )
    ]
 )

ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[['редко', 'иногда', 'средне', 'часто']],
                handle_unknown='use_encoded_value',
                unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# ### Обучение моделей
#
# Соберем финальный пайплайн и пропишем словарь гиперпараметров для каждой модели.

# %%
pipe_final= Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier())
    ]
)

params = [
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(3, 21),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 11),
        'models__min_samples_leaf': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    },
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True)],
        'models__kernel': ['rbf', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']

    },
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'models__solver': ['lbfgs', 'liblinear', 'newton-cholesky'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']
    }
]

# %% [markdown]
# ### Выбор лучшей модели
#
# Для выбора лучшей модели используем метрику ROC-AUC, так как она хорошо интерпретируется и учитывает ошибки обоих родов, а по условию задачи не очевидно, какой тип ошибок требует большего внимания.
#
# Мы задали множество вариантов для перебора, поэтому воспользуемся `RadomizedSearchCV` для экономии ресурсов.

# %%
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')

    search = RandomizedSearchCV(
        pipe_final,
        params,
        cv=5,
        scoring='roc_auc',
        n_iter=20,
        n_jobs=-1,
        random_state=RANDOM_STATE
    )
    search.fit(X_train, y_train)



print('Лучшая модель и её параметры:\n', search.best_estimator_)
print(search.best_params_)
print()
print ('Метрика ROC-AUC лучшей модели на тренировочной выборке:', search.best_score_)
# Out:
# Лучшая модель и её параметры:
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['тип_сервиса',
#                                                    'популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %%
best_model = search.best_estimator_.named_steps['models']
best_preprocessor = search.best_estimator_.named_steps['preprocessor']

X_test_pre = best_preprocessor.transform(X_test)
y_test_pred_proba = best_model.predict_proba(X_test_pre)

print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred_proba[:, 1])}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.917647534684302

# %% [markdown]
# Судя по полученным значениям метрики для обучающей и тестовой выборки, утечки не произошло и переобучения тоже: метрика на тестовой выборке чуть-чуть лучше метрики на тренировочной. Они обе довольно высоки, но не настолько близки к 1, чтобы вызывать подозрения.
#
# Лучше других моделей справилась `SVC()` с ядром `rbf`, для которой количественные признаки были масштабированы `RobustScaler()`.

# %% [markdown]
# ## Шаг 7. Анализ важности признаков
#
# Чтобы оценить важность признаков для лучшей модели, применим метод SHAP и построим график важности.

# %%
X_train_pre = best_preprocessor.transform(X_train)
X_train_samples = shap.utils.sample(X_train_pre, nsamples=30, random_state=RANDOM_STATE)
X_test_samples = shap.utils.sample(X_test_pre, nsamples=30, random_state=RANDOM_STATE)

feature_names = best_preprocessor.get_feature_names_out()

explainer = shap.KernelExplainer(best_model.predict_proba, X_train_samples, feature_names=feature_names)

shap_val = explainer.shap_values(X_test_samples)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_val[...,1], X_test_samples, feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.summary_plot(shap_val[...,1], X_test_samples, plot_type='bar', feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# ### Вывод по шагу 7
#
# Наиболее значительными для модели оказались признаки:
# * минуты на сайте в позапрошлом месяце;
# * количество просмотренных страниц за визит;
# * частота акционных покупок.
#
# Наименьшее влияние на ответы модели оказали признаки:
#
# * популярная категория;
# * тип сервиса;
# * число ошибок сервиса;
# * активность в текущем месяце;
# * длительность пользования сервисом.

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %% [markdown]
# ### Выбор группы покупателей и ее исследование
#
# В качестве группы выберем пользователей с типом сервиса "стандарт", которые часто пользуются акциями. На этапе исследовательского анализа мы заметили, что в этой группе много тех, чья активность снизилась.
#
# Соберем все данные об этих покупателях в отдельный датафрейм и проведем исследовательский анализ, сравнивая с несегментированной выборкой.

# %%
X = best_preprocessor.transform(market_full.drop(
        [
            'id',
            'покупательская_активность',
            'выручка_1_мес_назад',
            'выручка_текущий_месяц',
            'выручка_3_мес',
            'минуты_1_мес_назад',
            'минуты_текущий_месяц',
            'акционные_покупки',
            'разрешить_сообщать'
        ],
        axis=1
    ))

market_full[['вероятность_0', 'вероятность_1']] = pd.DataFrame(best_model.predict_proba(X))
market_full = market_full.merge(money, on='id')
display(market_full.head())
# Out:
#        id  покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                          1     премиум                 да
# 1  215350                          1    стандарт                нет
# 2  215351                          1    стандарт                 да
# 3  215352                          1    стандарт                нет
# 4  215353                          1    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  ...  \
# ...

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(
    data=market_full,
    x='вероятность_1',
    y='прибыль',
    hue='покупательская_активность'
)
plt.title('Диаграмма рассеяния прибыли и вероятности снижения активности')
plt.show()

# %% [markdown]
# Заметно, что для большинства клиентов со снизившейся активностью вероятность снижения была оценена выше 0.9. При высокой оценке вероятности модель очень редко ошибается. Поэтому целесообразно сосредоточиться на удержании именно таких клиентов.
#
# При этом получаемая от них прибыль колеблется в широком диапазоне: от 1 до 7 и более. Кажется разумным ограничить сегмент рамками прибыли от 2.5 до 5.5. Это наиболее перспективный сегмент с точки зрения совокупной прибыли.
#
# Соберем данные о входящих в выбранный сегмент клиентах в отдельную таблицу и проведем исследовательский анализ.

# %%
group = market_full.loc[
    (market_full['вероятность_1']>=0.9)
    & (market_full['прибыль']>=2.5)
    & (market_full['прибыль']<=5.5)
]

group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 304 entries, 0 to 1284
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   304 non-null    int64
#  1   покупательская_активность            304 non-null    int64
#  2   тип_сервиса                          304 non-null    object
#  3   разрешить_сообщать                   304 non-null    object
#  4   маркет_актив_6_мес                   304 non-null    float64
#  5   маркет_актив_тек_мес                 304 non-null    int64
#  6   длительность                         304 non-null    int64
#  7   акционные_покупки                    304 non-null    float64
#  8   популярная_категория                 304 non-null    object
#  9   средний_просмотр_категорий_за_визит  304 non-null    int64
#  10  неоплаченные_продукты_штук_квартал   304 non-null    int64
# ...

# %%
numeric_col = [
    'маркет_актив_6_мес',
    'маркет_актив_тек_мес',
    'длительность',
    'средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал',
    'ошибка_сервиса',
    'страниц_за_визит',
    'выручка_2_мес_назад',
    'выручка_1_мес_назад',
    'выручка_текущий_месяц',
    'выручка_3_мес',
    'минуты_1_мес_назад',
    'минуты_текущий_месяц',
    'минуты_2_мес',
    'прибыль']

for col in numeric_col:
    show_num(group, col)
    print('В несегментированной выборке')
    if col != 'прибыль':
        display(market_full[col].describe().to_frame())
    else:
        display(money[col].describe().to_frame())
# Out:
#        маркет_актив_6_мес
# count          304.000000
# mean             3.421382
# std              0.999424
# min              0.900000
# 25%              2.700000
# 50%              3.500000
# 75%              4.025000
# max              5.600000
# В несегментированной выборке
#        маркет_актив_6_мес
# count         1296.000000
# mean             4.256404
# std              1.013525
# min              0.900000
# 25%              3.700000
# 50%              4.200000
# 75%              4.900000
# max              6.600000
#        маркет_актив_тек_мес
# count            304.000000
# mean               4.019737
# std                0.698611
# min                3.000000
# 25%                4.000000
# 50%                4.000000
# 75%                5.000000
# max                5.000000
# В несегментированной выборке
#        маркет_актив_тек_мес
# count           1296.000000
# mean               4.009259
# std                0.696316
# min                3.000000
# ...

# %% [markdown]
# Предварительные выводы:
#
# 1. сниженная активность за 6 месяцев (ожидаемо);
# 2. активность в текущем месяце примерно такая же;
# 3. длительность в среднем вышее, распределение полимодальное, смещено вправо;
# 4. количество просмотренных категорий за визит меньше, распределение  смещено влево;
# 5. распределение числа неоплаченных продуктов более пологое, среднее больше медианы (в несегментированной выборке наоборот: медиана больше среднего);
# 6. количество ошибок сервиса немного меньше;
# 7. число просмотренных за визит страниц значительно меньше;
# 8. выручка приблизительно такая же в каждом периоде;
# 9. проводят примерно на 3 минуты меньше на сайте в месяц;
# 10. прибыль примерно такая же.

# %%
categorical_col = ['разрешить_сообщать',
                   'популярная_категория',
                   'частота_акционных_покупок']

for col in categorical_col:
    show_cat(group, col)
    print('В несегментированной выборке')
    show_cat(market_full, col)
# Out:
#      разрешить_сообщать  доля
# да                  224  0.74
# нет                  80  0.26
# В несегментированной выборке
#      разрешить_сообщать  доля
# да                  959  0.74
# нет                 337  0.26
#                                       популярная_категория  доля
# Товары для детей                                        89  0.29
# Домашний текстиль                                       65  0.21
# Косметика и аксесуары                                   64  0.21
# Кухонная посуда                                         51  0.17
# Техника для красоты и здоровья                          21  0.07
# Мелкая бытовая техника и электроника                    14  0.05
# В несегментированной выборке
#                                       популярная_категория  доля
# Товары для детей                                       329  0.25
# Домашний текстиль                                      250  0.19
# Косметика и аксесуары                                  223  0.17
# ...

# %% [markdown]
# Предварительные выводы:
#
# * доля разрешивших присылать сообщение такая же;
# * заметной разницы в популярных категориях нет;
# * увеличены доли тех, кто часто, средне и иногда пользуется акциями, почти нет тех, кто редко покупает что-то по акции.

# %% [markdown]
# ### Предложения, как увеличить покупательскую активность выбранной группы
#
# 1. Покупатели из выбранного сегмента обычно пользуются акциями. Возможно, снижение их активности связано с какими-либо изменениями акционной политики. Например, клиенты больше не видят интересующих их предложений, потому что такие предложения закончились. Либо потому что информация о таких предложениях не поступает. Если это верно, стоит рассмотреть возможность возвращения популярных акций. Либо выяснить, что изменилось в коммуникации с клиентами, и возобновить информирование.
#
# 2. Значительно сниженное число просмотренных за визит категорий, а так же заметно меньшее время на сайте могут говорить о том, что информация об акциях собрана на главной странице, и глубже нее выбранная группа идет редко. Возможно, есть смысл изменить отображение акций, чтобы заинтересовавшийся скидкой пользователь переходил в категорию и видел другие товары.
#
# 3. Поскольку у выбранной категории в среднем больше неоплаченных продуктов, и при этом такие пользователи значительно чаще среднего пользуются акциями, можно присылать им уведомления об акциях на неоплаченные товары из их корзин.

# %% [markdown]
# ## Шаг 9. Общий вывод
#
# 1. **Целью** была разработка решения, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность. Исходные данные включали признаки, описывающие:
# * коммуникацию сотрудников компании с клиентом;
# * продуктовое поведение;
# * покупательское поведение;
# * поведение на сайте.
# 2. Выполнили **предобработку данных**:
# * заполнять пропуски, преобразовывать типы данных и обрабатывать дубликаты не понадобилось;
# * привели названия столбцов к нижнему регистру, заменили в них пробелы на нижнее подчеркивание. Кириллическое написание оставлено для удобства понимания сути данных;
# * обнаружили и исправили опечатки в данных типа `object`.
# 3. Выполнили **исследовательский анализ данных**. Обнаружили:
# * в таблице `market_file`:
#     * отсутствуют аномальные значения, очень мало выбросов;
#     * 8 количественных признаков (из них 2 могут быть рассмотрены и как категориальные без дополнительных преобразований) и 4 категориальных;
#     * не все количественные признаки распределены нормально;
#     * все категориальные признаки распределены неравномерно;
#     * необходим учет дисбаланса классов;
#
# * в таблице `market_money_piv` (получена из таблицы `market_money`):
#     * 1 аномальное значение (удалили его), 3 выброса (проигнорировали при анализе);
#     * все распределения близки к нормальным;
#     * рост выручки, который может быть связан с сезонностью или/и с ростом цен;
#
# * в таблице `market_time_piv` (получена из таблицы `market_time`):
#     * отсутствуют аномальные значения, очень мало выбросов;
#     * рассмотрели 3 количественных признака (время, проведенное на сайте в разные месяцы и суммарно);
#     * распределения стремятся к нормальному, смещенному влево, скошенному вправо;
#     * в обоих месяцах медиана близка к среднему (около 13);
#     * в текущем месяце большинство пользователей проводит на сайте от 10 до 16 минут, то есть на 1 минуту меньше, чем в предыдущем;
#     * сумма за 2 месяца распределена более симметрично;
#
# * в таблице `money`:
#     * неясно, какие значения можно было бы счесть аномальными, поскольку неизвестно, в чем измеряется прибыль;
#     * выбросов мало, и они не очень сильно удалены от границ "усов" диаграммы размаха;
#     * распределение похоже на нормальное, смещенное вправо;
#     * медиана близка к среднему;
#     * график плотности распределения не пологий, немного скошен влево.
# 4. Объединили таблицы `market_file`, `market_money_piv` и `market_time_piv`.
# 5. Выполнили **корреляционный анализ**. Он показал взаимосвязи:
# * между количественными признаками:
#     * заметили 2 кластера взаимосвязанных признаков (большая часть связей сильная):
#       * связанный с выручкой:
#           * `выручка_2_мес_назад`;
#           * `выручка_1_мес_назад`;
#           * `выручка_текущий_месяц`;
#           * `выручка_3_мес`;
#       * связанный со временем на сайте:
#           * `минуты_1_мес_назад`;
#           * `минуты_текущий_месяц`;
#           * `минуты_2_мес`;
#     * других сильных связей нет;
#     * есть средние связи:
#       * `маркет_актив_6_мес` и кластер времени на сайте;
#       * `маркет_актив_6_мес` и `страниц_за_визит`;
#       * `акционные_покупки` и `страниц_за_визит`;
#       * `акционные_покупки` и кластер времени на сайте;
#       * `акционные_покупки` и кластер выручки;
#       * `страниц_за_визит` и `выручка_2_мес_назад`;
#       * `страниц_за_визит` и кластер времени на сайте;
#       * `выручка_2_мес_назад` и кластер времени на сайте;
#     * есть множество слабых связей;
# * между категориальными и количественными признаками:
#     * особенно сильных взаимосвязей нет;
#     * есть сильные связи:
#       * `покупательская_активность` и `страниц_за_визит`;
#       * `покупательская_активность` и `минуты_2_мес`.
#     * есть средние связи:
#       * `покупательская_активность` и `маркет_актив_6_мес`;
#       * `покупательская_активность` и `акционные_покупки`;
#       * `покупательская_активность` и `средний_просмотр_категорий_за_визит`;
#       * `покупательская_активность` и `неоплаченные_продукты_штук_квартал`;
#       * `покупательская_активность` и `выручка_2_мес_назад`;
#       * `покупательская_активность` и `минуты_1_мес_назад`;
#       * `покупательская_активность` и `минуты_текущий_месяц`;
#       * `тип_сервиса` и `длительность`;
#       * `частота_акционных_покупок` и `страниц_за_визит`;
#       * `частота_акционных_покупок` времени на сайте;
#     * есть слабые связи:
#       * `разрешить_сообщать` и `длительность`;
#       * `популярная_категория` и кластер выручки.
# * между категориальными признаками:
#     * доля покупателей со сниженной активностью сильно больше среди тех, кто часто, средне или хотя бы иногда пользовался акциями;
#     * среди премиум-пользователей доля сниженной активности немного больше;
#     * доля снизившейся активности меньше среди пользователей, выбирающих категории `Мелкая бытовая техника и электроника` и `Техника для красоты и здоровья`;
#     * доля снизившейся активности больше среди пользователей, выбирающих категории `Кухонная посуда`, `Косметика и аксессуары` и `Товары для детей`;
#     * разрешение сообщать дополнительную информацию не связано со снижением активности;
#     * среди премиум-пользователей доля сниженной активности немного больше.
# 6. Для устранения **мультиколлинеарности** решили:
# * выбрать из 2 кластеров (пункт 5.1.1) по одному признаку, оказывающему наибольшее влияние на целевой признак `покупательская активность` (определено в пункте 5.1.2):
#   * `минуты_2_мес`;
#   * `выручка_2_мес_назад`;
# * выбрать категориальную форму представления акционной активности.
# 7. Построили пайплайны для подготовки данных к обучению и обучения модели. Выбрали лучшую модель и ее гиперпараметры, а также лучший метод масштабирования. В основу отбора положили метрику ROC-AUC.
# 8. **Лучшая модель**: SVC с ядром rbf, для которой количественные признаки были масштабированы RobustScaler(). Она показала значение метрики 0.92 на тренирововчной выборке и 0.87 – на тестовой.
# 9. Методом SHAP проанализировали **важность признаков** для модели:
# * Наиболее значительными для модели оказались признаки:
#     * минуты на сайте в позапрошлом месяце;
#     * количество просмотренных страниц за визит;
#     * частота акционных покупок.
# * Наименьшее влияние на ответы модели оказали признаки:
#     * популярная категория
#     * тип сервиса
#     * число ошибок сервиса
#     * активность в текущем месяце
#     * длительность пользования сервисом
# 10. Выполнили **сегментацию покупателей**:
# * при помощи диаграммы рассеяния выбрали группу пользователей, для которых модель оценила вероятность снижения от 0.9 и выше, а получаемая прибыль находится в диапазоне от 2.5 до 5.5 включительно;
# * провели исследовательский анализ данных о выбранном сегменте и обнаружили, что по сравнению с несегментированной выборкой, для выбранной группы характерны следующие отличительные черты:
#     * сниженная активность за 6 месяцев (ожидаемо);
#     * длительность в среднем выше;
#     * количество просмотренных категорий за визит меньше;
#     * распределение числа неоплаченных продуктов более пологое, среднее больше медианы;
#     * число просмотренных за визит страниц значительно меньше;
#     * время на сайте примерно на 3 минуты меньше;
#     * доля пользователей со снизившейся активностью больше;
#     * доля разрешивших присылать сообщение такая же;
#     * увеличены доли тех, кто часто, средне и иногда пользуется акциями, почти нет тех, кто редко покупает что-то по акции;
#
# * сформулировали предложения, как увеличить покупательскую активность выбранной группы:
#     * рассмотреть возможные связи снижения активности клиентов с изменениями акционной или информационной политики (и соотвественно возобновить популярные акции или информирование);
#     * изменить отображение акций, чтобы заинтересовавшийся скидкой пользователь переходил в категорию и видел другие товары;
#     * присылать пользователям уведомления об акциях на неоплаченные товары из их корзин.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Очень приятно видеть вывод в конце проекта!\
# Приведены ответы на главные вопросы проекта.</font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера</b></font>\
# <font color='green'>Татьяна, хороший проект получился!
# Большое спасибо за проделанную работу. Видно, что приложено много усилий.
# Выводы и рассуждения получились содержательными, их было интересно читать.
# </font>
#
# <font color='steelblue'>Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)</font>
#
# <font color='blue'><b>Жду твой проект на повторном ревью. До встречи :) </b></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 2</b></font>\
# <font color='green'>Татьяна, большое спасибо за доработку.
# </font>
#
# <font color='blue'>Что нужно исправить:</font>
# <ul><font color='red'>Выведи важность признаков с shap.</font></ul>
#
# <font color='blue'>Что можно сделать лучше:</font>
# <font color='darkorange'>В работе я оставил несколько советов. Буду рад, если ты учтешь их.</font></ul>
#
# <font color='blue'><b>Жду новую версию проекта :)</b></font>

# %% [markdown]
# <div class="alert alert-info">
#
# __Комментарий студентки 2:__
#
# Я тебе очень благодарна за помощь! И за хорошие рекомендации. (Честно говоря, не представляю, что бы делала без подсказок.)
#
# Пора начинать сборный проект, так что пробовать использовать phik буду уже там, иначе, боюсь, не хватит времени.

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 3</b></font>\
# <font color='green'> Татьяна, проект принят! \
# Все этапы пройдены. Все рекомендации учтены.\
# Надеюсь, тебе понравился процесс выполнения и результат.</font> \
# <font color='blue'><b>Спасибо, удачи в освоении профессии!</b></font>
